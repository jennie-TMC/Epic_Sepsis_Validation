# %%
import os

root_dir = r"C:/Users/jenan/OneDrive - Tufts Medicine/code/EDSValidation_Jennie/Data"

for dirpath, dirnames, filenames in os.walk(root_dir):
    if "Time_Dependent_Data.csv" in filenames:
        file_path = os.path.join(dirpath, "Time_Dependent_Data.csv")
        try:
            os.remove(file_path)
            print(f"Deleted: {file_path}")
        except Exception as e:
            print(f"Failed to delete {file_path}: {e}")

# %%
from pathlib import Path

root_folder = Path(r"C:/Users/jenan/OneDrive - Tufts Medicine/code/EDSValidation_Jennie/Data")

files = list(root_folder.rglob("Time_Dependent_Data.csv"))

print(f"Found {len(files)} files:")
for f in files:
    print(f)
# Out:
# Found 61 files:
# C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_12_Lookback_1\Time_Dependent_Data.csv
# C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_12_Lookback_2\Time_Dependent_Data.csv
# C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_24_Lookback_1\Time_Dependent_Data.csv
# C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_24_Lookback_2\Time_Dependent_Data.csv
# C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_4_Lookback_1\Time_Dependent_Data.csv
# ...

# %%
from pathlib import Path

root_folder = Path(r"C:/Users/jenan/OneDrive - Tufts Medicine/code/EDSValidation_Jennie/Data") 

for file in root_folder.rglob("Time_Dependent_Data.csv"):
    print(f"Deleting: {file}")
    file.unlink()
# Out:
# Deleting: C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_12_Lookback_1\Time_Dependent_Data.csv
# Deleting: C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_12_Lookback_2\Time_Dependent_Data.csv
# Deleting: C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_24_Lookback_1\Time_Dependent_Data.csv
# Deleting: C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_24_Lookback_2\Time_Dependent_Data.csv
# Deleting: C:\Users\jenan\OneDrive - Tufts Medicine\code\EDSValidation_Jennie\Data\Time_Dependent_All\Refractory\Threshold_20_Lookforward_4_Lookback_1\Time_Dependent_Data.csv
# ...
